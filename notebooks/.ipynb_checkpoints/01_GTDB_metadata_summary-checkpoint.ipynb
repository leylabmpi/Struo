# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Goal" data-toc-modified-id="Goal-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Goal</a></span></li><li><span><a href="#Var" data-toc-modified-id="Var-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Var</a></span></li><li><span><a href="#Init" data-toc-modified-id="Init-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Init</a></span></li><li><span><a href="#Load" data-toc-modified-id="Load-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Load</a></span></li><li><span><a href="#Summarizing" data-toc-modified-id="Summarizing-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Summarizing</a></span><ul class="toc-item"><li><span><a href="#Representatives" data-toc-modified-id="Representatives-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Representatives</a></span></li><li><span><a href="#CheckM" data-toc-modified-id="CheckM-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>CheckM</a></span></li></ul></li><li><span><a href="#Selecting-the-best-rep-per-GTDB-species" data-toc-modified-id="Selecting-the-best-rep-per-GTDB-species-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Selecting the best rep per GTDB species</a></span><ul class="toc-item"><li><span><a href="#Summarizing-filtered" data-toc-modified-id="Summarizing-filtered-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Summarizing filtered</a></span></li><li><span><a href="#Writing-filtered-metadata-table" data-toc-modified-id="Writing-filtered-metadata-table-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Writing filtered metadata table</a></span></li><li><span><a href="#Filtering-by-checkM" data-toc-modified-id="Filtering-by-checkM-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Filtering by checkM</a></span></li></ul></li><li><span><a href="#sessionInfo" data-toc-modified-id="sessionInfo-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>sessionInfo</a></span></li></ul></div>

# %% [markdown]
# # Goal
#
# * Summarize GTDB metadata
# * The data will be used to select which genomes will be used for the `llmgp-db` pipeline

# %% [markdown]
# # Var

# %%
work_dir = '/ebio/abt3_projects/databases_no-backup/GTDB/'
bac_metadata_url = 'https://data.ace.uq.edu.au/public/gtdb/release86/bac_metadata_r86.tsv'
arc_metadata_url = 'https://data.ace.uq.edu.au/public/gtdb/release86/arc_metadata_r86.tsv'

# %% [markdown]
# # Init

# %%
library(dplyr)
library(tidyr)
library(ggplot2)
library(data.table)

set.seed(8473)

# %% [markdown]
# # Load

# %%
# reading in metadata
metadata_urls = c(bac_metadata_url, arc_metadata_url)

df = list()
for(url in metadata_urls){
    write(sprintf('Reading in file: %s', url), stderr())
    df[[url]] = fread(url, sep='\t', check.names=TRUE)
}
df = do.call(rbind, df)

df %>% nrow %>% print
df %>% head
# Out:
# [1] 127318
#   accession          scaffold_count gc_count longest_scaffold gc_percentage
# 1 RS_GCF_001245025.1 157            2457823   329958          52.25851
# 2 RS_GCF_000678935.1   4            2880443  3928455          65.59958
# 3 RS_GCF_000020485.1   1             976684  2578146          37.88319
# 4 RS_GCF_001206855.1  75             837175   119381          39.51367
# 5 RS_GCF_001085945.1  76             813113   115001          39.46670
# 6 RS_GCF_000659565.1   4            2886094  3927593          65.58749
#   total_gap_length genome_size n50_contigs n50_scaffolds l50_scaffolds ⋯
# 1    0             4703201      115698      115698       13            ⋯
# 2 6678             4397625     1025092     3928455        1            ⋯
# 3    0             2578146     2578146     2578146        1            ⋯
# 4   35             2118732       64912       64913       13            ⋯
# 5  101             2060352       47679       47680       14            ⋯
# 6 5261             4405634      762837     3927593        1            ⋯
#   ssu_silva_blast_evalue ssu_silva_blast_perc_identity lsu_5s_query_id
# 1 0                      100                           NZ_LHKW01000019.1
# 2 0                      100                           none
# 3 0                      100                           NC_011899.1
# 4 0                      99.935                        NZ_CRLU01000016.1
# 5 0                      99.935                        NZ_CKTI01000046.1
# 6 0                      100                           none
#   lsu_5s_length lsu_5s_contig_len
# 1 110           45304
# 2 none          none
# 3 110           2578146
# 4 108           45341
# 5 108           14629
# 6 none          none
#   gtdb_taxonomy
# 1 d__Bacteria;p__Proteobacteria;c__Gammaproteobacteria;o__Enterobacterales;f__Enterobacteriaceae;g__Salmonella;s__Salmonella enterica
# 2 d__Bacteria;p__Actinobacteriota;c__Actinobacteria;o__Corynebacteriales;f__Corynebacteriaceae;g__Mycobacterium;s__Mycobacterium tuberculosis
# 3 d__Bacteria;p__Firmicutes_F;c__Halanaerobiia;o__Halanaerobiales;f__Halothermotrichaceae;g__Halothermothrix;s__Halothermothrix orenii
# 4 d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales;f__Streptococcaceae;g__Streptococcus;s__Streptococcus pneumoniae
# 5 d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales;f__Streptococcaceae;g__Streptococcus;s__Streptococcus pneumoniae
# 6 d__Bacteria;p__Actinobacteriota;c__Actinobacteria;o__Corynebacteriales;f__Corynebacteriaceae;g__Mycobacterium;s__Mycobacterium tuberculosis
#   mimag_high_quality gtdb_cluster_size gtdb_clustered_genomes
# 1 f                  none              none
# 2 f                  none              none
# 3 t                  1                 RS_GCF_000020485.1
# 4 t                  none              none
# 5 t                  none              none
# 6 f                  none              none
#   gtdb_type_material
# 1 f
# 2 f
# 3 t
# 4 f
# 5 f
# 6 f

# %%
df %>% colnames
# Out:
#  [1] "accession"                       "scaffold_count"
#  [3] "gc_count"                        "longest_scaffold"
#  [5] "gc_percentage"                   "total_gap_length"
#  [7] "genome_size"                     "n50_contigs"
#  [9] "n50_scaffolds"                   "l50_scaffolds"
# [11] "contig_count"                    "ambiguous_bases"
# [13] "longest_contig"                  "l50_contigs"
# [15] "mean_scaffold_length"            "mean_contig_length"
# [17] "trna_aa_count"                   "trna_selenocysteine_count"
# [19] "trna_count"                      "checkm_completeness"
# [21] "checkm_contamination"            "protein_count"
# [23] "coding_bases"                    "coding_density"
# [25] "ssu_count"                       "checkm_marker_count"
# [27] "checkm_marker_lineage"           "checkm_marker_set_count"
# [29] "checkm_strain_heterogeneity"     "lsu_5s_count"
# [31] "ncbi_taxonomy"                   "gtdb_genome_representative"
# [33] "gtdb_representative"             "ncbi_taxonomy_unfiltered"
# [35] "ncbi_type_material"              "ncbi_biosample"
# [37] "ncbi_total_gap_length"           "ncbi_molecule_count"
# [39] "ncbi_date"                       "ncbi_submitter"
# [41] "ncbi_ncrna_count"                "ncbi_scaffold_n50"
# [43] "ncbi_assembly_name"              "ncbi_scaffold_n75"
# [45] "ncbi_protein_count"              "ncbi_assembly_type"
# [47] "ncbi_rrna_count"                 "ncbi_genbank_assembly_accession"
# [49] "ncbi_total_length"               "ncbi_unspanned_gaps"
# [51] "ncbi_taxid"                      "ncbi_trna_count"
# [53] "ncbi_genome_representation"      "ncbi_spanned_gaps"
# [55] "ncbi_translation_table"          "ncbi_scaffold_n90"
# [57] "ncbi_contig_count"               "ncbi_organism_name"
# [59] "ncbi_contig_n50"                 "ncbi_ungapped_length"
# [61] "ncbi_scaffold_l50"               "ncbi_ssu_count"
# [63] "ncbi_scaffold_count"             "ncbi_assembly_level"
# [65] "ncbi_refseq_category"            "ncbi_species_taxid"
# [67] "ncbi_isolate"                    "ncbi_wgs_master"
# [69] "ncbi_bioproject"                 "ncbi_seq_rel_date"
# [71] "ncbi_isolation_source"           "ncbi_country"
# [73] "ncbi_lat_lon"                    "ncbi_strain_identifiers"
# [75] "ssu_gg_taxonomy"                 "ssu_gg_blast_bitscore"
# [77] "ssu_gg_blast_subject_id"         "ssu_gg_blast_perc_identity"
# [79] "ssu_gg_blast_evalue"             "ssu_gg_blast_align_len"
# [81] "ssu_gg_query_id"                 "ssu_gg_length"
# [83] "ssu_silva_blast_bitscore"        "ssu_silva_taxonomy"
# [85] "ssu_silva_blast_subject_id"      "ssu_silva_blast_align_len"
# [87] "ssu_silva_blast_evalue"          "ssu_silva_blast_perc_identity"
# [89] "lsu_5s_query_id"                 "lsu_5s_length"
# [91] "lsu_5s_contig_len"               "gtdb_taxonomy"
# [93] "mimag_high_quality"              "gtdb_cluster_size"
# [95] "gtdb_clustered_genomes"          "gtdb_type_material"

# %% [markdown]
# # Summarizing

# %% [markdown]
# ## Representatives

# %%
# number of representatives
df %>%
    filter(gtdb_representative == 't') %>%
    nrow
# Out:
# [1] 28941

# %%
# number of representatives per species
df_s = df %>%
    filter(gtdb_representative == 't') %>%
    group_by(gtdb_taxonomy) %>%
    summarize(n=n()) %>%
    ungroup() 

df_s$n %>% summary %>% print
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   1.000   1.000   1.000   1.778   2.000 218.000

# %%
# assessing these multi-rep per species genomes
df_s %>%
    filter(n >= 2) %>%
    head(n=30)
# Out:
#    gtdb_taxonomy
# 1  d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__Altiarchaeales;f__Altiarchaeaceae;g__Altiarchaeum;s__Altiarchaeum sp1
# 2  d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__IMC4;f__WOR-SM1-SCG;g__WOR-SM1-SCG;s__
# 3  d__Archaea;p__Asgardarchaeota;c__Heimdallarchaeia;o__UBA460;f__UBA460;g__UBA460;s__
# 4  d__Archaea;p__Asgardarchaeota;c__Lokiarchaeia;o__Thorarchaeales;f__Thorarchaeaceae;g__SMTZ1-45;s__
# 5  d__Archaea;p__Crenarchaeota;c__Bathyarchaeia;o__40CM-2-53-6;f__40CM-2-53-6;g__40CM-2-53-6;s__
# 6  d__Archaea;p__Crenarchaeota;c__Bathyarchaeia;o__40CM-2-53-6;f__40CM-2-53-6;g__40CM-2-53-6;s__40CM-2-53-6 sp
# 7  d__Archaea;p__Crenarchaeota;c__Bathyarchaeia;o__B26-1;f__B26-1;g__B26-1;s__
# 8  d__Archaea;p__Crenarchaeota;c__Bathyarchaeia;o__B26-1;f__UBA233;g__UBA11855;s__UBA11855 sp1
# 9  d__Archaea;p__Crenarchaeota;c__Bathyarchaeia;o__B26-1;f__UBA233;g__UBA233;s__
# 10 d__Archaea;p__Crenarchaeota;c__Bathyarchaeia;o__TCS64;f__TCS64;g__RBG-16-57-9;s__RBG-16-57-9 sp1
# 11 d__Archaea;p__Crenarchaeota;c__Bathyarchaeia;o__TCS64;f__TCS64;g__UBA8941;s__
# 12 d__Archaea;p__Crenarchaeota;c__Methanomethylicia;o__Methanomethyliales;f__Methanomethyliaceae;g__Methanomethylicus;s__Methanomethylicus mesodigestum
# 13 d__Archaea;p__Crenarchaeota;c__Nitrososphaeria;o__Caldiarchaeales;f__JGI-OTU-1;g__JGI-OTU-1;s__JGI-OTU-1 sp1
# 14 d__Archaea;p__Crenarchaeota;c__Nitrososphaeria;o__Nitrososphaerales;f__Nitrosopumilaceae;g__Nitrosoarchaeum;s__
# 15 d__Archaea;p__Crenarchaeota;c__Nitrososphaeria;o__Nitrososphaerales;f__Nitrosopumilaceae;g__Nitrosopelagicus;s__
# 16 d__Archaea;p__Crenarchaeota;c__Nitrososphaeria;o__Nitrososphaerales;f__Nitrosopumilaceae;g__Nitrosopelagicus;s__Nitrosopelagicus sp2
# 17 d__Archaea;p__Crenarchaeota;c__Nitrososphaeria;o__Nitrososphaerales;f__Nitrosopumilaceae;g__Nitrosopumilus;s__
# 18 d__Archaea;p__Crenarchaeota;c__Nitrososphaeria;o__Nitrososphaerales;f__Nitrosopumilaceae;g__Nitrosopumilus;s__Nitrosopumilus sp1
# 19 d__Archaea;p__Crenarchaeota;c__Nitrososphaeria;o__Nitrososphaerales;f__Nitrosopumilaceae;g__Nitrosotalea;s__
# 20 d__Archaea;p__Crenarchaeota;c__Nitrososphaeria;o__Nitrososphaerales;f__Nitrosopumilaceae;g__Nitrosotalea;s__Nitrosotalea sp1
# 21 d__Archaea;p__Crenarchaeota;c__Nitrososphaeria;o__Nitrososphaerales;f__Nitrosopumilaceae;g__Nitrosotenuis;s__
# 22 d__Archaea;p__Crenarchaeota;c__Nitrososphaeria;o__Nitrososphaerales;f__Nitrosopumilaceae;g__Nitrosotenuis;s__Nitrosotenuis sp1
# 23 d__Archaea;p__Crenarchaeota;c__Nitrososphaeria;o__Nitrososphaerales;f__Nitrososphaeraceae;g__Nitrososphaera;s__Nitrososphaera sp1
# 24 d__Archaea;p__Crenarchaeota;c__Nitrososphaeria;o__Nitrososphaerales;f__Nitrososphaeraceae;g__UBA10452;s__UBA10452 sp1
# 25 d__Archaea;p__Crenarchaeota;c__Nitrososphaeria;o__Nitrososphaerales;f__UBA213;g__UBA213;s__
# 26 d__Archaea;p__Crenarchaeota;c__Nitrososphaeria;o__Nitrososphaerales;f__UBA57;g__UBA57;s__
# 27 d__Archaea;p__Crenarchaeota;c__Nitrososphaeria;o__Nitrososphaerales;f__UBA57;g__UBA57;s__UBA57 sp1
# 28 d__Archaea;p__Crenarchaeota;c__Thermoprotei;o__Desulfurococcales;f__Acidilobaceae;g__Acidilobus;s__Acidilobus sp1
# 29 d__Archaea;p__Crenarchaeota;c__Thermoprotei;o__Desulfurococcales;f__Acidilobaceae;g__Aeropyrum;s__Aeropyrum camini
# 30 d__Archaea;p__Crenarchaeota;c__Thermoprotei;o__Desulfurococcales;f__Desulfurococcaceae;g__Desulfurococcus;s__Desulfurococcus amylolyticus
#    n
# 1   8
# 2   2
# 3   2
# 4   2
# 5   4
# 6   3
# 7   3
# 8   2
# 9   2
# 10  2
# 11  2
# 12  2
# 13  2
# 14  4
# 15  5
# 16  5
# 17 13
# 18  5
# 19  5
# 20  2
# 21  2
# 22  8
# 23  5
# 24  6
# 25  2
# 26  4
# 27  2
# 28  2
# 29  2
# 30  2

# %%
# number of representatives per species
df_s = df %>%
    filter(gtdb_representative == 't') %>%
    group_by(ncbi_species_taxid) %>%
    summarize(n=n()) %>%
    ungroup() 

df_s$n %>% summary %>% print
# Out:
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    1.000    1.000    1.000    1.336    1.000 1719.000

# %%
# number of representatives per species
df_s = df %>%
    filter(gtdb_representative == 't') %>%
    group_by(ncbi_species_taxid) %>%
    summarize(n=n()) %>%
    ungroup() %>%
    filter(ncbi_species_taxid != 'none')

df_s$n %>% summary %>% print
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   1.000   1.000   1.000   1.257   1.000 135.000

# %% [markdown]
# ## CheckM

# %%
df$checkm_completeness %>% summary %>% print
df$checkm_contamination %>% summary %>% print
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    0.57   99.01   99.53   96.77   99.94  100.00
#     Min.  1st Qu.   Median     Mean  3rd Qu.     Max.
#    0.000    0.040    0.250    0.836    0.740 3196.760

# %%
# plotting association
p = df %>%
    filter(checkm_contamination <= 100) %>%
    ggplot(aes(checkm_completeness, checkm_contamination)) +
    geom_point(alpha=0.3) +
    facet_grid(. ~ gtdb_representative) +
    theme_bw()

options(repr.plot.width=6, repr.plot.height=3)
plot(p)
# Out:
# plot without title

# %% [markdown]
# # Selecting the best rep per GTDB species

# %%
# ranking based on checkM data
df_s = df %>%
    filter(gtdb_representative == 't') %>%
    group_by(gtdb_taxonomy) %>%
    mutate(checkm_completeness_rank = min_rank(-checkm_completeness),
           checkm_contamination_rank = min_rank(checkm_contamination),
           summed_rank = min_rank(checkm_completeness_rank + checkm_contamination_rank),
           min_summed_rank = min(summed_rank)) %>%
    ungroup() 

df_s %>% nrow %>% print
df_s %>% head
# Out:
# [1] 28941
#   accession          scaffold_count gc_count longest_scaffold gc_percentage
# 1 RS_GCF_000020485.1   1             976684  2578146          37.88319
# 2 RS_GCF_000468955.1   1             867523  2427048          35.74396
# 3 RS_GCF_000426145.1  31            1773896   651440          33.71697
# 4 RS_GCF_000347175.1 125            1884499   295179          42.47804
# 5 RS_GCF_000381545.1  51            2169018   627008          41.82851
# 6 RS_GCF_000284375.1   1            5861934  9207384          63.66558
#   total_gap_length genome_size n50_contigs n50_scaffolds l50_scaffolds ⋯
# 1    0             2578146     2578146     2578146        1            ⋯
# 2    0             2427048     2427048     2427048        1            ⋯
# 3 3127             5264264      337455      476216        5            ⋯
# 4    0             4436408       68494       68494       17            ⋯
# 5 8199             5193701      194487      212581        7            ⋯
# 6    0             9207384     9207384     9207384        1            ⋯
#   lsu_5s_contig_len
# 1 2578146
# 2 2427048
# 3 70526
# 4 127119
# 5 113481
# 6 9207384
#   gtdb_taxonomy
# 1 d__Bacteria;p__Firmicutes_F;c__Halanaerobiia;o__Halanaerobiales;f__Halothermotrichaceae;g__Halothermothrix;s__Halothermothrix orenii
# 2 d__Bacteria;p__Firmicutes;c__Bacilli;o__Lactobacillales;f__Streptococcaceae;g__Lactococcus;s__Lactococcus lactis_B
# 3 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Flavobacteriales;f__Flavobacteriaceae;g__Flavobacterium;s__
# 4 d__Bacteria;p__Spirochaetota;c__Leptospirae;o__Leptospirales;f__Leptospiraceae;g__Leptospira;s__Leptospira alstonii
# 5 d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Cytophagales;f__Cyclobacteriaceae;g__Rhodonellum;s__Rhodonellum psychrophilum
# 6 d__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Rhizobiales;f__Xanthobacteraceae;g__Bradyrhizobium;s__Bradyrhizobium japonicum
#   mimag_high_quality gtdb_cluster_size
# 1 t                  1
# 2 t                  33
# 3 f                  1
# 4 t                  3
# 5 t                  2
# 6 t                  4
#   gtdb_clustered_genomes
# 1 RS_GCF_000020485.1
# 2 GB_GCA_900240855.1;GB_GCA_900240895.1;GB_GCA_900240885.1;RS_GCF_000805435.1;RS_GCF_001591705.1;RS_GCF_000468955.1;GB_GCA_000447925.1;RS_GCF_001622295.1;RS_GCF_000236475.1;RS_GCF_002078955.1;GB_GCA_000447965.1;RS_GCF_001622215.1;GB_GCA_900240865.1;RS_GCF_002078915.1;RS_GCF_001622375.1;GB_GCA_000447845.1;GB_GCA_900240905.1;RS_GCF_001622205.1;RS_GCF_001645365.1;RS_GCF_001622405.1;GB_GCA_000447825.1;RS_GCF_002078375.1;GB_GCA_000447885.1;RS_GCF_002078895.1;RS_GCF_002078935.1;RS_GCF_002441765.1;RS_GCF_001622315.1;RS_GCF_002563595.1;RS_GCF_000534815.1;RS_GCF_001622365.1;RS_GCF_002078765.1;RS_GCF_000014545.1;RS_GCF_000312685.1
# 3 RS_GCF_000426145.1
# 4 RS_GCF_001569445.1;RS_GCF_000347175.1;RS_GCF_001568455.1
# 5 RS_GCF_000473765.1;RS_GCF_000381545.1
# 6 RS_GCF_001038185.1;RS_GCF_000284375.1;RS_GCF_000472985.1;RS_GCF_000773865.1
#   gtdb_type_material checkm_completeness_rank checkm_contamination_rank
# 1 t                  1                         1
# 2 f                  1                         1
# 3 f                  1                        40
# 4 t                  1                         1
# 5 t                  1                         1
# 6 t                  1                         1
#   summed_rank min_summed_rank
# 1  1          1
# 2  1          1
# 3 22          1
# 4  1          1
# 5  1          1
# 6  1          1

# %%
# assessing
df_s %>%
    dplyr::select(gtdb_taxonomy, checkm_completeness, checkm_contamination,
                  checkm_completeness_rank, checkm_contamination_rank, 
                  summed_rank, min_summed_rank) %>%
    arrange(gtdb_taxonomy) %>%
    head(n=20)
# Out:
#    gtdb_taxonomy
# 1  d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__Altiarchaeales;f__Altiarchaeaceae;g__Altiarchaeum;s__
# 2  d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__Altiarchaeales;f__Altiarchaeaceae;g__Altiarchaeum;s__Altiarchaeum sp1
# 3  d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__Altiarchaeales;f__Altiarchaeaceae;g__Altiarchaeum;s__Altiarchaeum sp1
# 4  d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__Altiarchaeales;f__Altiarchaeaceae;g__Altiarchaeum;s__Altiarchaeum sp1
# 5  d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__Altiarchaeales;f__Altiarchaeaceae;g__Altiarchaeum;s__Altiarchaeum sp1
# 6  d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__Altiarchaeales;f__Altiarchaeaceae;g__Altiarchaeum;s__Altiarchaeum sp1
# 7  d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__Altiarchaeales;f__Altiarchaeaceae;g__Altiarchaeum;s__Altiarchaeum sp1
# 8  d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__Altiarchaeales;f__Altiarchaeaceae;g__Altiarchaeum;s__Altiarchaeum sp1
# 9  d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__Altiarchaeales;f__Altiarchaeaceae;g__Altiarchaeum;s__Altiarchaeum sp1
# 10 d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__IMC4;f__IMC4;g__IMC4;s__
# 11 d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__IMC4;f__WOR-SM1-SCG-A;g__WOR-SM1-SCG-A;s__
# 12 d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__IMC4;f__WOR-SM1-SCG;g__WOR-SM1-SCG;s__
# 13 d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__IMC4;f__WOR-SM1-SCG;g__WOR-SM1-SCG;s__
# 14 d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__ltiarchaeales-1;f__ltiarchaeales-1;g__ltiarchaeales-1;s__
# 15 d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__SCGC-AAA252-I15;f__ex4484-2;g__ex4484-2;s__
# 16 d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__SCGC-AAA252-I15;f__ex4484-96;g__ex4484-96;s__
# 17 d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__SCGC-AAA252-I15;f__SCGC-AAA252-I15;g__SCGC-AAA252-I15;s__
# 18 d__Archaea;p__Asgardarchaeota;c__Heimdallarchaeia;o__LC-2;f__LC-2;g__GCA-2728275;s__
# 19 d__Archaea;p__Asgardarchaeota;c__Heimdallarchaeia;o__LC-2;f__LC-2;g__LC-2;s__
# 20 d__Archaea;p__Asgardarchaeota;c__Heimdallarchaeia;o__LC-3;f__LC-3;g__LC-3;s__
#    checkm_completeness checkm_contamination checkm_completeness_rank
# 1  77.41               0.93                 1
# 2  86.60               0.93                 4
# 3  71.96               0.93                 8
# 4  87.31               0.93                 3
# 5  95.02               0.93                 1
# 6  86.60               0.93                 4
# 7  83.80               0.93                 6
# 8  95.02               1.87                 1
# 9  80.06               0.93                 7
# 10 79.12               2.81                 1
# 11 79.06               5.14                 1
# 12 76.88               3.12                 1
# 13 58.28               0.00                 2
# 14 77.41               1.87                 1
# 15 81.80               1.98                 1
# 16 66.77               0.93                 1
# 17 62.31               0.93                 1
# 18 83.18               1.87                 1
# 19 72.43               4.21                 1
# 20 91.59               5.61                 1
#    checkm_contamination_rank summed_rank min_summed_rank
# 1  1                         1           1
# 2  1                         3           1
# 3  1                         7           1
# 4  1                         2           1
# 5  1                         1           1
# 6  1                         3           1
# 7  1                         5           1
# 8  8                         7           1
# 9  1                         6           1
# 10 1                         1           1
# 11 1                         1           1
# 12 2                         1           1
# 13 1                         1           1
# 14 1                         1           1
# 15 1                         1           1
# 16 1                         1           1
# 17 1                         1           1
# 18 1                         1           1
# 19 1                         1           1
# 20 1                         1           1

# %%
# filtering
df_s_f = df_s %>%
    filter(summed_rank == min_summed_rank) %>%
    group_by(gtdb_taxonomy) %>%
    sample_n(1) %>%
    ungroup() %>%
    dplyr::select(-checkm_completeness_rank, -checkm_contamination_rank, 
                  -summed_rank, -min_summed_rank)

df_s_f %>% nrow %>% print
df_s_f %>% head
# Out:
# [1] 16275
#   accession          scaffold_count gc_count longest_scaffold gc_percentage
# 1 GB_GCA_002083985.1 209            460016     18515          31.82530
# 2 GB_GCA_002785505.1 251            484743     34633          32.45002
# 3 GB_GCA_001742785.1   1            666033   1390915          48.47673
# 4 GB_GCA_001723845.1 300            946468     62700          37.12188
# 5 GB_GCA_001723855.1 170            852561     80876          40.83209
# 6 GB_GCA_002841105.1 358            663592     33644          33.06645
#   total_gap_length genome_size n50_contigs n50_scaffolds l50_scaffolds ⋯
# 1  1492            1446933      6430          6957       74            ⋯
# 2  5109            1498923      5943          8320       53            ⋯
# 3 16992            1390915      9252       1390915        1            ⋯
# 4   113            2549736     15854         16971       47            ⋯
# 5     0            2087968     15808         15808       45            ⋯
# 6  6139            2012983      7574          9550       61            ⋯
#   ssu_silva_blast_evalue ssu_silva_blast_perc_identity lsu_5s_query_id
# 1 none                   none                          MTER01000144.1
# 2 0                      97.109                        PEUK01000019.1
# 3 0                      99.707                        MCBF01000001.1
# 4 0                      85.518                        none
# 5 0                      86.304                        MCBC01000145.1
# 6 0                      99.105                        PHDY01000210.1
#   lsu_5s_length lsu_5s_contig_len
# 1 105           4010
# 2 106           8675
# 3 106           1390915
# 4 none          none
# 5 107           16369
# 6 91            3962
#   gtdb_taxonomy
# 1 d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__Altiarchaeales;f__Altiarchaeaceae;g__Altiarchaeum;s__
# 2 d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__Altiarchaeales;f__Altiarchaeaceae;g__Altiarchaeum;s__Altiarchaeum sp1
# 3 d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__IMC4;f__IMC4;g__IMC4;s__
# 4 d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__IMC4;f__WOR-SM1-SCG-A;g__WOR-SM1-SCG-A;s__
# 5 d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__IMC4;f__WOR-SM1-SCG;g__WOR-SM1-SCG;s__
# 6 d__Archaea;p__Altiarchaeota;c__Altiarchaeia;o__ltiarchaeales-1;f__ltiarchaeales-1;g__ltiarchaeales-1;s__
#   mimag_high_quality gtdb_cluster_size gtdb_clustered_genomes
# 1 f                  1                 GB_GCA_002083985.1
# 2 f                  1                 GB_GCA_002785505.1
# 3 f                  1                 GB_GCA_001742785.1
# 4 f                  1                 GB_GCA_001723845.1
# 5 f                  1                 GB_GCA_001723855.1
# 6 f                  1                 GB_GCA_002841105.1
#   gtdb_type_material
# 1 f
# 2 f
# 3 f
# 4 f
# 5 f
# 6 f

# %% [markdown]
# ## Summarizing filtered

# %%
# number of representatives per species
df_s_f_s = df_s_f %>%
    group_by(gtdb_taxonomy) %>%
    summarize(n=n()) %>%
    ungroup() 

df_s_f_s$n %>% summary %>% print
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       1       1       1       1       1       1

# %%
df_s_f$checkm_completeness %>% summary %>% print
df_s_f$checkm_contamination %>% summary %>% print
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   27.08   93.00   99.09   93.59   99.73  100.00
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#  0.0000  0.0000  0.5500  0.9396  1.2900 13.7900

# %%
# plotting association
p = df_s_f %>%
    ggplot(aes(checkm_completeness, checkm_contamination, color=mimag_high_quality)) +
    geom_point(alpha=0.3) +
    theme_bw()

options(repr.plot.width=5, repr.plot.height=3)
plot(p)
# Out:
# plot without title

# %% [markdown]
# ## Writing filtered metadata table

# %%
F = file.path(work_dir, 'release86_metadata_1perSpec.tsv')
write.table(df_s_f, file=F, sep='\t', quote=FALSE, row.names=FALSE)
cat('File written:', F, '\n')
# Out:
# File written: /ebio/abt3_projects/databases_no-backup/GTDB//release86_metadata_1perSpec.tsv

# %% [markdown]
# ## Filtering by checkM

# %%
# all
df_s_f %>% nrow %>% print

# relaxed
df_s_f %>%
    filter(checkm_completeness >= 70,
           checkm_contamination <= 10) %>%
    nrow %>% print

# stringent
df_s_f %>%
    filter(checkm_completeness >= 70,
           checkm_contamination <= 5) %>%
    nrow %>% print
# Out:
# [1] 16275
# [1] 15217
# [1] 14930

# %% [markdown]
# # sessionInfo

# %%
sessionInfo()
# Out:
# R version 3.4.1 (2017-06-30)
# Platform: x86_64-pc-linux-gnu (64-bit)
# Running under: Ubuntu 18.04.1 LTS
#
# Matrix products: default
# BLAS: /ebio/abt3_projects/software/miniconda3_gt4.4/envs/py3_physeq/lib/R/lib/libRblas.so
# LAPACK: /ebio/abt3_projects/software/miniconda3_gt4.4/envs/py3_physeq/lib/R/lib/libRlapack.so
#
# locale:
# [1] en_US.UTF-8
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
# [1] bindrcpp_0.2.2    data.table_1.11.4 ggplot2_3.0.0     tidyr_0.8.1
# [5] dplyr_0.7.6
#
# loaded via a namespace (and not attached):
#  [1] Rcpp_0.12.17     pillar_1.2.2     compiler_3.4.1   plyr_1.8.4
#  [5] bindr_0.1.1      base64enc_0.1-3  tools_3.4.1      digest_0.6.15
#  [9] uuid_0.1-2       jsonlite_1.5     evaluate_0.10.1  tibble_1.4.2
# [13] gtable_0.2.0     pkgconfig_2.0.1  rlang_0.2.1      IRdisplay_0.4.4
# [17] curl_3.2         IRkernel_0.8.12  repr_0.15.0      withr_2.1.1
# [21] stringr_1.3.1    grid_3.4.1       tidyselect_0.2.4 glue_1.3.0
# [25] R6_2.2.2         pbdZMQ_0.3-2     reshape2_1.4.3   purrr_0.2.4
# [29] magrittr_1.5     scales_0.5.0     htmltools_0.3.6  assertthat_0.2.0
# [33] colorspace_1.3-2 labeling_0.3     stringi_1.2.3    lazyeval_0.2.1
# [37] munsell_0.5.0    crayon_1.3.4
